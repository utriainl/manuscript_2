# %%
import pygrib
import matplotlib.pyplot as plt

# %%
era5fname = '/home/sm_aital/rsb27/BRIGHT/data_ERA5/HCLIM_grib/ERA5_NEUR_202307061500+000H00M'
grbs_era = pygrib.open(era5fname)

for igrb in [16]: #range(1,grbs_era.messages+1):
               

    grb_var = grbs_era.message(igrb)

    print(igrb,grb_var)

    lats, lons = grb_var.latlons()

    plt.pcolormesh(lons,lats,grb_var.values)
    plt.colorbar()
# Out:
# 16 16:Skin temperature:K (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 202307060000
